# %%
#데이터 불러오기
import pandas as pd
main_df2019 = pd.read_csv("C:/Users/ahn/Downloads/water_2019.csv", encoding = 'CP949')  #CP949
main_df2020 = pd.read_csv("C:/Users/ahn/Desktop/water_2020.csv", encoding = 'CP949')
main_df2021 = pd.read_csv("C:/Users/ahn/Desktop/water_2021.csv", encoding = 'CP949')

# %%
#결측치 확인
print(main_df2021.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  365 non-null    int64
#  1   bBac        365 non-null    int64
#  2   bBod        365 non-null    float64
#  3   bCod        332 non-null    float64
#  4   bSs         365 non-null    float64
#  5   bTn         365 non-null    float64
#  6   bTp         365 non-null    float64
#  7   bVal        365 non-null    object
#  8   loccd       365 non-null    int64
#  9   locnm       365 non-null    object
#  10  temper      365 non-null    float64
#  11  uBac        365 non-null    object
#  12  uBod        365 non-null    float64
#  13  uCod        332 non-null    float64
#  14  uSs         365 non-null    float64
#  15  uTn         365 non-null    float64
#  16  uTp         365 non-null    float64
#  17  uVal        365 non-null    object
#  18  weather     365 non-null    object
# ...

# %%
main_df2021['bCod'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 360     True
# 361     True
# 362     True
# 363     True
# 364     True
# Name: bCod, Length: 365, dtype: bool

# %%
main_df2021['uCod'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 360     True
# 361     True
# 362     True
# 363     True
# 364     True
# Name: uCod, Length: 365, dtype: bool

# %%
#!pip install missingno 설치
import missingno as msno
msno.matrix(main_df2021)
# Out:
# <AxesSubplot:>

# %%
msno.bar(main_df2021);

# %%
#결측치 제거
main_df2021.dropna(subset=['bCod', 'uCod'], axis = 0, inplace = True)

# %%
#필요없는 열 제거
main_df2019.drop(['Unnamed: 0','loccd','locnm'], axis =1)
# Out:
#      bBac  bBod  bCod  bSs     bTn    bTp   bVal  temper     uBac   uBod  \
# 0       0   0.5   6.2  1.0  13.129  0.098  1,789    -5.0  198,000  271.8
# 1       0   0.6   6.3  0.9  14.291  0.105  1,777    -4.9  206,000  269.4
# 2       0   0.4   6.7  1.0  13.920  0.109  1,847    -3.5  107,000  262.2
# 3       0   0.6   6.9  1.5  11.174  0.109  1,898    -1.1  116,000  202.2
# 4       0   0.6   6.8  1.0  10.287  0.106  1,672    -2.8  101,000    216
# ..    ...   ...   ...  ...     ...    ...    ...     ...      ...    ...
# 360     2   1.8   6.7  1.8   6.659  0.066  1,832    -1.7  119,000    376
# 361     3   1.6   6.8  2.8   5.654  0.074  1,771     1.1   55,000    259
# 362     2   1.2   6.0  1.9   6.177  0.053  1,811     3.8   23,000    246
# 363     1   1.5   6.9  2.6   6.794  0.076  2,040     2.7   19,000    288
# 364     3   1.7   6.4  2.5   8.836  0.069  1,819    -7.9   92,000  300.8
#
#       uCod    uSs     uTn    uTp   uVal weather        wqdt  wtemper
# ...

# %%
main_df2020.drop(['Unnamed: 0','loccd','locnm'], axis =1)
# Out:
#      bBac  bBod  bCod  bSs    bTn    bTp   bVal  temper     uBac   uBod  \
# 0       2   1.4   6.2  1.8  7.921  0.070  1,677    -2.2   15,000  348.0
# 1       5   1.6   6.5  2.2  7.969  0.077  1,871     1.0   76,000  317.3
# 2       3   2.0   6.7  2.2  7.698  0.073  1,889    -0.1   61,000  349.5
# 3       2   1.3   7.0  2.5  6.218  0.083  1,824     1.2   18,000  366.0
# 4       3   1.1   6.5  2.0  6.493  0.071  1,828     1.3   45,000  281.0
# ..    ...   ...   ...  ...    ...    ...    ...     ...      ...    ...
# 361     1   1.1   7.4  1.8  7.062  0.050  2,059     4.0  120,000  199.0
# 362     2   0.6   7.3  2.2  8.336  0.050  1,995     5.5   68,000  179.0
# 363     9   0.3   7.6  1.7  8.208  0.054  1,930     0.8  140,000  274.0
# 364     0   0.4   7.5  1.8  7.508  0.048  2,099     8.8   71,000  246.0
# 365     1   0.5   7.4  1.5  7.945  0.044  2,142     8.6    4,500  252.0
#
#       uCod    uSs      uTn    uTp   uVal weather        wqdt  wtemper
# ...

# %%
main_df2021.drop(['Unnamed: 0','loccd','locnm'], axis =1)
# Out:
#      bBac  bBod  bCod  bSs    bTn    bTp   bVal  temper     uBac   uBod  \
# 0       2   0.7   6.2  1.6  9.080  0.041  2,009    -5.2   36,000  344.0
# 1       1   0.8   6.6  2.0  9.632  0.041  1,993    -4.4   22,000  246.0
# 2       1   0.8   6.3  1.7  8.257  0.043  1,953    -4.0    9,500  191.4
# 3       0   0.4   6.6  1.7  8.848  0.046  2,109    -2.8   14,000  198.0
# 4       0   0.4   7.1  2.0  8.492  0.016  2,055    -3.4   37,000  170.4
# ..    ...   ...   ...  ...    ...    ...    ...     ...      ...    ...
# 327     6   0.7   7.6  0.6  6.180  0.068  1,993     5.9  260,000  415.5
# 328     1   0.6   7.3  1.2  5.843  0.048  2,004     7.9  140,000  376.5
# 329     1   1.1   6.4  1.3  5.680  0.043  1,950     5.5   52,000  406.5
# 330     4   0.8   6.9  1.0  5.895  0.043  2,087     4.2  160,000  375.0
# 331     2   0.9   4.7  0.9  5.297  0.041  2,035     5.3  160,000  379.5
#
#       uCod    uSs     uTn    uTp   uVal weather        wqdt  wtemper
# ...
