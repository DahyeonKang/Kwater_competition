# %% [markdown]
# ## 🥰 R로 API 불러온 결과입니다.
#
# ### 📅 2019-01-01 ~ 2019-07-19 (200일) 동안의 하수처리장 수질 데이터입니다~

# %%
install.packages("httr") # HTTP통신을 위한 패키지 설치
install.packages("jsonlite")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(httr)
library(jsonlite)

# %%
res <- GET('http://opendata.kwater.or.kr/openapi-data/service/pubd/sewerage/waterQuality/day/list?serviceKey=GGsw%2BIOUyPbAeasUiCPaom5zocqK4ZEqIIQHUeswsYlOwZyQugsX3cAC1jqRcp4ZNurICccEoINxdefuy2LGEQ%3D%3D&pageNo=1&numOfRows=200&stDt=2019-01-01&edDt=2021-11-30&loccd=47000')

# %%
print(x=res)
# Out:
# Response [http://opendata.kwater.or.kr/openapi-data/service/pubd/sewerage/waterQuality/day/list?serviceKey=GGsw%2BIOUyPbAeasUiCPaom5zocqK4ZEqIIQHUeswsYlOwZyQugsX3cAC1jqRcp4ZNurICccEoINxdefuy2LGEQ%3D%3D&pageNo=1&numOfRows=200&stDt=2019-01-01&edDt=2021-11-30&loccd=47000]
#   Date: 2022-05-09 11:52
#   Status: 200
#   Content-Type: application/json;charset=UTF-8
#   Size: 59.1 kB

# %%
tt <- httr::content(res, "text")

# %%
data <- jsonlite::fromJSON(tt)

# %%
data
# Out:
# $response
# $response$header
# $response$header$resultCode
# [1] "00"
#
# $response$header$resultMsg
# [1] "NORMAL SERVICE."
#
#
# $response$body
# $response$body$items
# $response$body$items$item
#     bBac bBod bCod bSs    bTn   bTp  bVal loccd                locnm temper
# 1      0  0.5  6.2 1.0 13.129 0.098 1,789 47000 연서공공하수처리시설   -5.0
# 2      0  0.6  6.3 0.9 14.291 0.105 1,777 47000 연서공공하수처리시설   -4.9
# 3      0  0.4  6.7 1.0 13.920 0.109 1,847 47000 연서공공하수처리시설   -3.5
# 4      0  0.6  6.9 1.5 11.174 0.109 1,898 47000 연서공공하수처리시설   -1.1
# 5      0  0.6  6.8 1.0 10.287 0.106 1,672 47000 연서공공하수처리시설   -2.8
# 6      0  0.5  6.6 1.1  9.589 0.093 1,669 47000 연서공공하수처리시설   -2.8
# 7      0  0.3  7.4 1.2 11.651 0.084 1,691 47000 연서공공하수처리시설   -1.9
# 8      1  0.6  6.0 1.1 10.320 0.090 1,759 47000 연서공공하수처리시설   -3.5
# 9      0  0.5  6.1 1.2  9.029 0.099 1,701 47000 연서공공하수처리시설   -4.7
# 10     1  0.5  6.2 1.0  9.361 0.096 1,784 47000 연서공공하수처리시설   -0.6
# ...

# %%
data$response$body$items$item
# Out:
#     bBac bBod bCod bSs bTn    bTp   bVal  loccd locnm                temper
# 1   0    0.5  6.2  1.0 13.129 0.098 1,789 47000 연서공공하수처리시설 -5.0
# 2   0    0.6  6.3  0.9 14.291 0.105 1,777 47000 연서공공하수처리시설 -4.9
# 3   0    0.4  6.7  1.0 13.920 0.109 1,847 47000 연서공공하수처리시설 -3.5
# 4   0    0.6  6.9  1.5 11.174 0.109 1,898 47000 연서공공하수처리시설 -1.1
# 5   0    0.6  6.8  1.0 10.287 0.106 1,672 47000 연서공공하수처리시설 -2.8
# 6   0    0.5  6.6  1.1 9.589  0.093 1,669 47000 연서공공하수처리시설 -2.8
# 7   0    0.3  7.4  1.2 11.651 0.084 1,691 47000 연서공공하수처리시설 -1.9
# 8   1    0.6  6.0  1.1 10.320 0.090 1,759 47000 연서공공하수처리시설 -3.5
# 9   0    0.5  6.1  1.2 9.029  0.099 1,701 47000 연서공공하수처리시설 -4.7
# 10  1    0.5  6.2  1.0 9.361  0.096 1,784 47000 연서공공하수처리시설 -0.6
# 11  0    0.5  6.9  1.6 9.315  0.094 1,967 47000 연서공공하수처리시설  2.4
# 12  1    0.5  6.6  1.7 8.051  0.114 1,877 47000 연서공공하수처리시설  2.8
# 13  1    0.5  6.5  1.6 7.359  0.097 1,751 47000 연서공공하수처리시설  1.2
# ...
